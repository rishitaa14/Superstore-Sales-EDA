# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../input/sales-forecasting/train.csv')

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
# Display a concise summary of the DataFrame
# This includes information on the index, column names, non-null counts, data types, and memory usage.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
# Display the first 5 rows of the DataFrame
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
# Calculate the number of unique values in each column of the DataFrame to understand the diversity of the data in each column.
df.nunique()
# Out:
# Row ID           9800
# Order ID         4922
# Order Date       1230
# Ship Date        1326
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# Country             1
# City              529
# State              49
# Postal Code       626
# Region              4
# Product ID       1861
# Category            3
# Sub-Category       17
# Product Name     1849
# Sales            5757
# dtype: int64

# %%
# Identify and display rows that are duplicates in the DataFrame
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales]
# Index: []

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %%
df.drop(columns=["Row ID",'Order ID'],inplace=True)

# %%
df.head()
# Out:
#    Order Date   Ship Date       Ship Mode Customer ID    Customer Name  \
# 0  08/11/2017  11/11/2017    Second Class    CG-12520      Claire Gute
# 1  08/11/2017  11/11/2017    Second Class    CG-12520      Claire Gute
# 2  12/06/2017  16/06/2017    Second Class    DV-13045  Darrin Van Huff
# 3  11/10/2016  18/10/2016  Standard Class    SO-20335   Sean O'Donnell
# 4  11/10/2016  18/10/2016  Standard Class    SO-20335   Sean O'Donnell
#
#      Segment        Country             City       State  Postal Code Region  \
# 0   Consumer  United States        Henderson    Kentucky      42420.0  South
# 1   Consumer  United States        Henderson    Kentucky      42420.0  South
# 2  Corporate  United States      Los Angeles  California      90036.0   West
# 3   Consumer  United States  Fort Lauderdale     Florida      33311.0  South
# 4   Consumer  United States  Fort Lauderdale     Florida      33311.0  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
df.describe()
# Out:
#         Postal Code         Sales
# count   9789.000000   9800.000000
# mean   55273.322403    230.769059
# std    32041.223413    626.651875
# min     1040.000000      0.444000
# 25%    23223.000000     17.248000
# 50%    58103.000000     54.490000
# 75%    90008.000000    210.605000
# max    99301.000000  22638.480000

# %%
df.describe(include="O")
# Out:
#         Order Date   Ship Date       Ship Mode Customer ID  Customer Name  \
# count         9800        9800            9800        9800           9800
# unique        1230        1326               4         793            793
# top     05/09/2017  26/09/2018  Standard Class    WB-21850  William Brown
# freq            38          34            5859          35             35
#
#          Segment        Country           City       State Region  \
# count       9800           9800           9800        9800   9800
# unique         3              1            529          49      4
# top     Consumer  United States  New York City  California   West
# freq        5101           9800            891        1946   3140
#
#              Product ID         Category Sub-Category     Product Name
# count              9800             9800         9800             9800
# unique             1861                3           17             1849
# ...

# %%
df.isnull().sum()
# Out:
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df[df['Postal Code'].isnull()]
# Out:
#       Order Date   Ship Date       Ship Mode Customer ID     Customer Name  \
# 2234  05/12/2018  10/12/2018  Standard Class    QJ-19255      Quincy Jones
# 5274  07/11/2016  09/11/2016    Second Class    SV-20785  Stewart Visinsky
# 8798  06/04/2017  10/04/2017  Standard Class    VM-21685   Valerie Mitchum
# 9146  23/01/2017  27/01/2017  Standard Class    CB-12535  Claudia Bergmann
# 9147  23/01/2017  27/01/2017  Standard Class    CB-12535  Claudia Bergmann
# 9148  23/01/2017  27/01/2017  Standard Class    CB-12535  Claudia Bergmann
# 9386  19/01/2018  23/01/2018  Standard Class    RM-19375     Raymond Messe
# 9387  19/01/2018  23/01/2018  Standard Class    RM-19375     Raymond Messe
# 9388  19/01/2018  23/01/2018  Standard Class    RM-19375     Raymond Messe
# 9389  19/01/2018  23/01/2018  Standard Class    RM-19375     Raymond Messe
# 9741  08/11/2016  12/11/2016  Standard Class    QJ-19255      Quincy Jones
#
# ...

# %%
df['Postal Code'] = df['Postal Code'].fillna(5401)

# %%
df.isnull().sum()
# Out:
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# dtype: int64

# %%
df.head()
# Out:
#    Order Date   Ship Date       Ship Mode Customer ID    Customer Name  \
# 0  08/11/2017  11/11/2017    Second Class    CG-12520      Claire Gute
# 1  08/11/2017  11/11/2017    Second Class    CG-12520      Claire Gute
# 2  12/06/2017  16/06/2017    Second Class    DV-13045  Darrin Van Huff
# 3  11/10/2016  18/10/2016  Standard Class    SO-20335   Sean O'Donnell
# 4  11/10/2016  18/10/2016  Standard Class    SO-20335   Sean O'Donnell
#
#      Segment        Country             City       State  Postal Code Region  \
# 0   Consumer  United States        Henderson    Kentucky      42420.0  South
# 1   Consumer  United States        Henderson    Kentucky      42420.0  South
# 2  Corporate  United States      Los Angeles  California      90036.0   West
# 3   Consumer  United States  Fort Lauderdale     Florida      33311.0  South
# 4   Consumer  United States  Fort Lauderdale     Florida      33311.0  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'],format='%d/%m/%Y')
df['Ship Date'] = pd.to_datetime(df['Ship Date'],format='%d/%m/%Y')
df['Postal Code'] = df['Postal Code'].astype(int)

# %%
df.sample(5)
# Out:
#      Order Date  Ship Date       Ship Mode Customer ID    Customer Name  \
# 3049 2018-04-02 2018-04-04     First Class    TC-21475     Tony Chapman
# 402  2015-12-24 2015-12-26     First Class    LF-17185      Luke Foster
# 3844 2015-10-28 2015-10-31     First Class    TS-21370     Todd Sumrall
# 4501 2015-06-30 2015-07-04  Standard Class    MS-17980  Michael Stewart
# 5118 2016-09-26 2016-10-03  Standard Class    GM-14500     Gene McClure
#
#           Segment        Country         City       State  Postal Code  \
# 3049  Home Office  United States     Columbus     Georgia        31907
# 402      Consumer  United States        Miami     Florida        33180
# 3844    Corporate  United States  Los Angeles  California        90049
# 4501    Corporate  United States      Houston       Texas        77095
# 5118     Consumer  United States    Oceanside    New York        11572
#
#        Region       Product ID         Category Sub-Category  \
# ...

# %%
df['Segment'].value_counts()
# Out:
# Segment
# Consumer       5101
# Corporate      2953
# Home Office    1746
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Segment'])
# Out:
# <Axes: xlabel='Segment', ylabel='count'>

# %%
df['Category'].value_counts()
# Out:
# Category
# Office Supplies    5909
# Furniture          2078
# Technology         1813
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
df['Category'].value_counts().plot(kind='bar')
plt.title('Frequency of Product Categories')
plt.xlabel('Category')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(12, 8))
df['State'].value_counts().plot(kind='bar')
plt.title('Frequency of States')
plt.xlabel('State')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Sales', y='Category', data=df)
plt.title('Sales Distribution by Category')
plt.xlabel('Sales')
plt.ylabel('Category')
plt.show()

# %%
plt.figure(figsize=(12, 6))
df.groupby('Sub-Category')['Sales'].sum().sort_values().plot(kind='bar')
plt.title('Total Sales by Product Sub-Category')
plt.xlabel('Sub-Category')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Correlation of Features**

# %%
pivot_table = df.pivot_table(index='Region', columns='Category', values='Sales', aggfunc='sum')
plt.figure(figsize=(10, 6))
sns.heatmap(pivot_table, annot=True, cmap='YlGnBu', linewidths=0.5, fmt = '.2f')
plt.title('Sales by Region and Category')
plt.xlabel('Category')
plt.ylabel('Region')
plt.show()

# %%
df.set_index('Order Date', inplace=True)

plt.figure(figsize=(12, 6))
df['Sales'].resample('M').sum().plot()
plt.title('Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.show()
# Out:
# /tmp/ipykernel_18/1112843458.py:4: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df['Sales'].resample('M').sum().plot()
